# %%
import numpy as np
from imps import iMPS

# %%
def pcoin(p):
    """
    transition matrix for pcoin

    -------------------
    Parameters
    -------------------
    p:float
    -------------------
    
    """
    T0 = np.array([
        [1.-p,p],
        [0.,0.]
    ])
    T1 = np.array([
        [0.,0.],
        [p,1.-p]
    ])
    return np.array([T0,T1])

# %%
p = 0.1
imps_pcoin = iMPS.from_tmatrix(pcoin(p))
U = imps_pcoin.to_unitary()

# %%
U
# Out:
# array([[ 9.48683298e-01+0.j,  1.19971216e-17+0.j, -1.09634524e-16+0.j,
#          3.16227766e-01+0.j],
#        [ 2.77555756e-17+0.j,  9.48683298e-01+0.j,  3.16227766e-01+0.j,
#         -9.62356811e-18+0.j],
#        [ 3.16227766e-01+0.j, -8.23578933e-18+0.j, -3.19189120e-17+0.j,
#         -9.48683298e-01+0.j],
#        [ 1.11022302e-16+0.j, -3.16227766e-01+0.j,  9.48683298e-01+0.j,
#          7.83378531e-18+0.j]])
